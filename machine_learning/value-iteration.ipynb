# %% [markdown]
# ## Value Iteration Algorithm
# ***

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gamma = 0.5
num_state = 5 
num_action = 3 
num_iter = 10

# %%
# Transition probabilities 
# Each of the states s
# Each of the actions a (left, stay, right)
# Probability from s with a to s'
T = np.array([ 
    [
        [1/2,1/2,0,0,0], 
        [1/2,1/2,0,0,0], 
        [2/3,1/3,0,0,0]
    ], [
        [1/3,2/3,0,0,0], 
        [1/4,1/2,1/4,0,0], 
        [0,2/3,1/3,0,0]
    ], [
        [0,1/3,2/3,0,0], 
        [0,1/4,1/2,1/4,0], 
        [0,0,2/3,1/3,0]
    ], [
        [0,0,1/3,2/3,0], 
        [0,0,1/4,1/2,1/4], 
        [0,0,0,2/3,1/3]
    ], [
        [0,0,0,1/3,2/3], 
        [0,0,0,1/2,1/2], 
        [0,0,0,1/2,1/2]
    ], 
])

# %%
# Initializing state values
V_0 = np.zeros(num_state)

# Rewards only based on state
R = np.zeros(num_state)
R[4] = 1

# %% [markdown]
# $$V_{\blue{k+1}}^\star(s)=\max_a
# \left[
# \sum_{s^\prime} T(s,a,s^\prime)*\Big(R(s,a,s^\prime) + \gamma V_{\blue{k}}^\star(s^\prime)\Big)
# \right]

# %%
def value_iteration(V_0: np.array, T: np.array, gamma: float) -> np.array:
    """
    Perform value iteration to find the optimal state values for a Markov decision process.

    Args:
        V_0 (np.array): 1D numpy array of shape (n_states,) containing the initial estimates of the 
            state values.
        T (np.array): 3D numpy array of shape (n_states, n_actions, n_states) representing the 
            transition probabilities for the Markov decision process. T[s, a, t] is the probability 
            of transitioning to state t when taking action a from state s.
        gamma (float): Scalar between 0 and 1 representing the discount factor for future rewards.

    Returns:
        np.array: 1D numpy array of shape (n_states,) containing the optimal state values for the 
            Markov decision process.
    """
    # new state values
    V_1 = np.empty(num_state)

    # Iterate over all starting states
    for s in range(num_state):
        # Q-values of best actions
        V_s = np.inf*-1

        # Iterate over all actions given a starting state
        for a in range(num_action):
            # Probability weighted Q-value of given state-action
            Q_sa = 0

            # Iterate over target states given starting state and action
            for t in range(num_state):
                Q_sa += T[s][a][t]*(R[s]+gamma*V_0[t])
            
            # State value is the Q-value for the optimal action
            V_s = max(V_s, Q_sa)
        
        # Collect the state values of each state into an array
        V_1[s] = V_s

    return V_1

# %%
arr = np.empty((10, 5))

for i in range(10):
    V_1 = value_iteration(V_0=V_0, T=T, gamma=gamma)
    V_0 = V_1
    arr[i] = V_1

print(V_1)
# Out:
# [0.00761459 0.02415681 0.09904883 0.39902345 1.59902343]

# %%
sns.heatmap(arr, annot=True, cmap="coolwarm", fmt=".2f", cbar=False, edgecolor="w", lw=0.2)
plt.show()
